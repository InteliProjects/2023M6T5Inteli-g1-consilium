# %%
# %%capture
import sys
# !{sys.executable} -m pip install pandas
# !{sys.executable} -m pip install seaborn;

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df_poligonos = pd.read_csv("../dados/poligonos.txt", encoding='iso-8859-1')

# %% [markdown]
# # Serviços

# %%
df_poligonos.shape
# Out:
# (28, 7)

# %%
df_poligonos.head(28)
# Out:
#              Nome Nome do polígono  \
# 0   PR.CNM.ATT.11   PR_ATT_ATCA_02
# 1   PR.CNM.ATT.11   PR_ATT_ATCA_01
# 2   PR.CNM.BOV.11   PR_BOV_CTBV_01
# 3   PR.CNM.CBX.11   PR_CBX_CBFB_01
# 4   PR.CNM.CBX.11   PR_CBX_CBGT_01
# 5   PR.CSM.TAR.11   PR_CTA_CTCJ_01
# 6   PR.CSM.TAR.11   PR_CTA_CTCJ_05
# 7   PR.CSM.TAR.11   PR_CTA_CTCJ_02
# 8   PR.CWN.CEO.11   PR_CTA_CTJE_01
# 9   PR.CWN.CEO.11   PR_CTA_CTJE_02
# 10  PR.CWN.CEO.11   PR_CTA_CTJE_03
# 11  PR.CWN.CEO.11   PR_CTA_CTJE_04
# 12  PR.CWN.CEO.12   PR_CTA_CTME_03
# 13  PR.CWN.CEO.12   PR_CTA_CTME_02
# 14  PR.CWN.SFE.11   PR_CTA_CTSF_01
# 15  PR.CWS.ARR.11   PR_CTA_CTAC_01
# 16  PR.CWS.ARR.12   PR_CTA_CTAC_02
# 17  PR.CWS.ARR.13   PR_CTA_CTAC_03
# 18  PR.CWS.BOQ.11   PR_CTA_CTBQ_01
# 19  PR.CWS.PIN.11   PR_CTA_CTPI_01
# 20  PR.CWS.PIN.11   PR_CTA_CTPI_02
# 21  PR.MGA.MGA.11   PR_MGA_MGNM_01
# 22  PR.MGA.MGA.11   PR_MGA_MGNM_03
# 23  PR.MGA.MGA.11   PR_MGA_MGNM_04
# 24  PR.MGA.MGA.11   PR_MGA_MGNM_05
# 25  PR.MGA.MGA.11    PR_MGA_FOE_01
# 26  PR.MGA.MGA.11    PR_MGA_PNU_01
# 27  PR.MGA.MGA.11   PR_MGA_MGNM_02
#
#                                       Detalhes de KML Latitude mínima  \
# 0   <?xml version="1.0" encoding="UTF-8"?>\n    <k...      -25,368178
# 1   <?xml version="1.0" encoding="UTF-8"?>\n    <k...      -25,371808
# 2   <?xml version="1.0" encoding="UTF-8"?>\n    <k...      -25,413761
# 3   <?xml version="1.0" encoding="UTF-8"?>\n    <k...      -25,329203
# 4   <?xml version="1.0" encoding="UTF-8"?>\n    <k...      -25,393699
# 5   <?xml version="1.0" encoding="UTF-8"?>\n    <k...      -25,480175
# 6   <?xml version="1.0" encoding="UTF-8"?>\n    <k...      -25,457746
# 7   <?xml version="1.0" encoding="UTF-8"?>\n    <k...      -25,436467
# 8   <?xml version="1.0" encoding="UTF-8"?>\n    <k...      -25,449329
# 9   <?xml version="1.0" encoding="UTF-8"?>\n    <k...      -25,468079
# 10  <?xml version="1.0" encoding="UTF-8"?>\n    <k...      -25,479275
# 11  <?xml version="1.0" encoding="UTF-8"?>\n    <k...      -25,468753
# 12  <?xml version="1.0" encoding="UTF-8"?>\n    <k...      -25,472761
# 13  <?xml version="1.0" encoding="UTF-8"?>\n    <k...      -25,424502
# 14  <?xml version="1.0" encoding="UTF-8"?>\n    <k...      -25,484369
# 15  <?xml version="1.0" encoding="UTF-8"?>\n    <k...      -25,615790
# 16  <?xml version="1.0" encoding="UTF-8"?>\n    <k...      -25,563856
# 17  <?xml version="1.0" encoding="UTF-8"?>\n    <k...      -25,645386
# 18  <?xml version="1.0" encoding="UTF-8"?>\n    <k...      -25,529553
# 19  <?xml version="1.0" encoding="UTF-8"?>\n    <k...      -25,532249
# 20  <?xml version="1.0" encoding="UTF-8"?>\n    <k...      -25,522114
# 21  <?xml version="1.0" encoding="UTF-8"?>\n    <k...      -23,419243
# 22  <?xml version="1.0" encoding="UTF-8"?>\n    <k...      -23,433819
# 23  <?xml version="1.0" encoding="UTF-8"?>\n    <k...      -23,476760
# 24  <?xml version="1.0" encoding="UTF-8"?>\n    <k...      -23,481460
# 25  <?xml version="1.0" encoding="UTF-8"?>\n    <k...      -23,631583
# 26  <?xml version="1.0" encoding="UTF-8"?>\n    <k...      -23,477312
# 27  <?xml version="1.0" encoding="UTF-8"?>\n    <k...      -23,476848
#
#    Latitude máxima Longitude mínima Longitude máxima
# 0       -25,337352       -49,316598       -49,269103
# 1       -25,268543       -49,347761       -49,228031
# 2       -25,349405       -49,283833       -49,193188
# 3       -25,258635       -49,265300       -49,173859
# 4       -25,322236       -49,245601       -49,172572
# 5       -25,429769       -49,253472       -49,192461
# 6       -25,422355       -49,265196       -49,230133
# 7       -25,393581       -49,265065       -49,193746
# 8       -25,415145       -49,313792       -49,260299
# 9       -25,435109       -49,304624       -49,247695
# 10      -25,450708       -49,279589       -49,253462
# 11      -25,446753       -49,262204       -49,242978
# 12      -25,402750       -49,340413       -49,279191
# 13      -25,361222       -49,323296       -49,240658
# 14      -25,333769       -49,395281       -49,303279
# 15      -25,524446       -49,307503       -49,216779
# 16      -25,503355       -49,346411       -49,246148
# 17      -25,553604       -49,365851       -49,301146
# 18      -25,456383       -49,281578       -49,184978
# 19      -25,459780       -49,323175       -49,262406
# 20      -25,462358       -49,359500       -49,291417
# 21      -23,365478       -52,010163       -51,902445
# 22      -23,364596       -51,932353       -51,826600
# 23      -23,411152       -52,010471       -51,931797
# 24      -23,410594       -51,939779       -51,885480
# 25      -23,592850       -52,099003       -52,052354
# 26      -23,436841       -52,078082       -52,006585
# 27      -23,416136       -51,905161       -51,810833
